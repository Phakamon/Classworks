# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
Fdata = pd.read_excel('fishdata1.xlsx')

# %%
Fdata
# Out:
#           S.No    Year  Month   Day  Hour  Minute  Second   PM1  PM2.5  PM10  \
# 0          1.0  2019.0   11.0  26.0  10.0    27.0    20.0   8.0   12.0  14.0
# 1          2.0  2019.0   11.0  26.0  10.0    28.0    12.0   9.0   12.0  15.0
# 2          3.0  2019.0   11.0  26.0  10.0    29.0     4.0  10.0   14.0  15.0
# 3          4.0  2019.0   11.0  26.0  10.0    29.0    56.0   8.0   12.0  12.0
# 4          5.0  2019.0   11.0  26.0  10.0    30.0    43.0   9.0   12.0  15.0
# ...        ...     ...    ...   ...   ...     ...     ...   ...    ...   ...
# 23531  23532.0  2019.0   12.0  10.0   8.0     8.0    23.0  18.0   27.0  28.0
# 23532  23533.0  2019.0   12.0  10.0   8.0     9.0     9.0  19.0   33.0  48.0
# 23533  23534.0  2019.0   12.0  10.0   8.0     9.0    57.0  22.0   30.0  34.0
# 23534  23535.0  2019.0   12.0  10.0   8.0    10.0    49.0  21.0   35.0  47.0
# 23535  23536.0  2019.0   12.0  10.0   8.0    11.0    41.0  23.0   34.0  39.0
#
#        ...  Unnamed: 46  Unnamed: 47  Unnamed: 48  Unnamed: 49  Unnamed: 50  \
# 0      ...          NaN          NaN          NaN          NaN          NaN
# 1      ...          NaN          NaN          NaN          NaN          NaN
# 2      ...          NaN          NaN          NaN          NaN          NaN
# 3      ...          NaN          NaN          NaN          NaN          NaN
# 4      ...          NaN          NaN          NaN          NaN          NaN
# ...    ...          ...          ...          ...          ...          ...
# 23531  ...          NaN          NaN          NaN          NaN          NaN
# 23532  ...          NaN          NaN          NaN          NaN          NaN
# 23533  ...          NaN          NaN          NaN          NaN          NaN
# 23534  ...          NaN          NaN          NaN          NaN          NaN
# 23535  ...          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 51  Unnamed: 52  Unnamed: 53  Unnamed: 54  Unnamed: 55
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 23531          NaN          NaN          NaN          NaN          NaN
# 23532          NaN          NaN          NaN          NaN          NaN
# 23533          NaN          NaN          NaN          NaN          NaN
# 23534          NaN          NaN          NaN          NaN          NaN
# 23535          NaN          NaN          NaN          NaN          NaN
#
# [23536 rows x 56 columns]

# %%
Fdata.dtypes
# Out:
# S.No           float64
# Year           float64
# Month          float64
# Day            float64
# Hour           float64
# Minute         float64
# Second         float64
# PM1            float64
# PM2.5          float64
# PM10           float64
# Temp           float64
# Humidity       float64
# Light          float64
# CO             float64
# Water Temp     float64
# pH             float64
# Unnamed: 16    float64
# Unnamed: 17    float64
# Unnamed: 18    float64
# Unnamed: 19    float64
# Unnamed: 20    float64
# Unnamed: 21    float64
# Unnamed: 22    float64
# Unnamed: 23    float64
# Unnamed: 24    float64
# Unnamed: 25    float64
# Unnamed: 26    float64
# Unnamed: 27    float64
# Unnamed: 28    float64
# Unnamed: 29    float64
# Unnamed: 30    float64
# Unnamed: 31    float64
# Unnamed: 32    float64
# Unnamed: 33    float64
# Unnamed: 34    float64
# Unnamed: 35    float64
# Unnamed: 36    float64
# Unnamed: 37    float64
# Unnamed: 38    float64
# Unnamed: 39    float64
# Unnamed: 40    float64
# Unnamed: 41    float64
# Unnamed: 42    float64
# Unnamed: 43    float64
# Unnamed: 44    float64
# Unnamed: 45    float64
# Unnamed: 46    float64
# Unnamed: 47    float64
# Unnamed: 48    float64
# Unnamed: 49    float64
# Unnamed: 50    float64
# Unnamed: 51    float64
# Unnamed: 52    float64
# Unnamed: 53    float64
# Unnamed: 54    float64
# Unnamed: 55    float64
# dtype: object

# %%
Fdata[:].isnull().sum()
# Out:
# S.No               0
# Year               0
# Month              0
# Day                0
# Hour               0
# Minute             0
# Second             0
# PM1              241
# PM2.5              0
# PM10               0
# Temp               0
# Humidity           0
# Light              0
# CO                 0
# Water Temp        80
# pH               815
# Unnamed: 16    23536
# Unnamed: 17    23536
# Unnamed: 18    23536
# Unnamed: 19    23536
# Unnamed: 20    23536
# Unnamed: 21    23536
# Unnamed: 22    23536
# Unnamed: 23    23536
# Unnamed: 24    23536
# Unnamed: 25    23536
# Unnamed: 26    23536
# Unnamed: 27    23536
# Unnamed: 28    23536
# Unnamed: 29    23536
# Unnamed: 30    23536
# Unnamed: 31    23536
# Unnamed: 32    23536
# Unnamed: 33    23536
# Unnamed: 34    23536
# Unnamed: 35    23536
# Unnamed: 36    23536
# Unnamed: 37    23536
# Unnamed: 38    23536
# Unnamed: 39    23536
# Unnamed: 40    23470
# Unnamed: 41    23470
# Unnamed: 42    23483
# Unnamed: 43    23513
# Unnamed: 44    23532
# Unnamed: 45    23532
# Unnamed: 46    23532
# Unnamed: 47    23532
# Unnamed: 48    23532
# Unnamed: 49    23532
# Unnamed: 50    23532
# Unnamed: 51    23532
# Unnamed: 52    23532
# Unnamed: 53    23532
# Unnamed: 54    23532
# Unnamed: 55    23533
# dtype: int64

# %%
#Fdata=Fdata[['PM1','PM2.5','PM10','Temp','Humidity','Light','CO','Water Temp','pH']]

# %%
Fdata = Fdata.loc[:, 'PM1':'pH']

# %%
Fdata.head()
# Out:
#     PM1  PM2.5  PM10  Temp  Humidity  Light    CO  Water Temp    pH
# 0   8.0   12.0  14.0  25.0      91.0   34.0  95.0       24.63  6.52
# 1   9.0   12.0  15.0  25.0      91.0   34.0  95.0       24.63  6.59
# 2  10.0   14.0  15.0  26.0      89.0   34.0  95.0       24.63  6.53
# 3   8.0   12.0  12.0  26.0      90.0   34.0  95.0       24.56  6.59
# 4   9.0   12.0  15.0  26.0      91.0   34.0  95.0       24.56  6.54

# %%
Fdata.shape
# Out:
# (23536, 9)

# %%
Fdata.tail()
# Out:
#         PM1  PM2.5  PM10  Temp  Humidity  Light    CO  Water Temp    pH
# 23531  18.0   27.0  28.0  45.0     -13.0   35.0  95.0       27.06  6.34
# 23532  19.0   33.0  48.0  47.0       9.0   35.0  95.0       27.06  6.35
# 23533  22.0   30.0  34.0  47.0       8.0   35.0  95.0       27.06  6.34
# 23534  21.0   35.0  47.0  51.0       6.0   34.0  95.0       27.06  6.38
# 23535  23.0   34.0  39.0  47.0       8.0   34.0  95.0       27.06  6.34

# %%
Fdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23536 entries, 0 to 23535
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   PM1         23295 non-null  float64
#  1   PM2.5       23536 non-null  float64
#  2   PM10        23536 non-null  float64
#  3   Temp        23536 non-null  float64
#  4   Humidity    23536 non-null  float64
#  5   Light       23536 non-null  float64
#  6   CO          23536 non-null  float64
#  7   Water Temp  23456 non-null  float64
#  8   pH          22721 non-null  float64
# dtypes: float64(9)
# memory usage: 1.6 MB

# %%
Fdata.isnull().sum()
# Out:
# PM1           241
# PM2.5           0
# PM10            0
# Temp            0
# Humidity        0
# Light           0
# CO              0
# Water Temp     80
# pH            815
# dtype: int64

# %%
new_Fdata = Fdata
Fdata.mean()
new_Fdata.fillna(Fdata.mean(),inplace = False)
# Out:
#         PM1  PM2.5  PM10  Temp  Humidity  Light    CO  Water Temp    pH
# 0       8.0   12.0  14.0  25.0      91.0   34.0  95.0       24.63  6.52
# 1       9.0   12.0  15.0  25.0      91.0   34.0  95.0       24.63  6.59
# 2      10.0   14.0  15.0  26.0      89.0   34.0  95.0       24.63  6.53
# 3       8.0   12.0  12.0  26.0      90.0   34.0  95.0       24.56  6.59
# 4       9.0   12.0  15.0  26.0      91.0   34.0  95.0       24.56  6.54
# ...     ...    ...   ...   ...       ...    ...   ...         ...   ...
# 23531  18.0   27.0  28.0  45.0     -13.0   35.0  95.0       27.06  6.34
# 23532  19.0   33.0  48.0  47.0       9.0   35.0  95.0       27.06  6.35
# 23533  22.0   30.0  34.0  47.0       8.0   35.0  95.0       27.06  6.34
# 23534  21.0   35.0  47.0  51.0       6.0   34.0  95.0       27.06  6.38
# 23535  23.0   34.0  39.0  47.0       8.0   34.0  95.0       27.06  6.34
#
# [23536 rows x 9 columns]

# %%
new_Fdata.isnull().sum()
# Out:
# PM1           0
# PM2.5         0
# PM10          0
# Temp          0
# Humidity      0
# Light         0
# CO            0
# Water Temp    0
# pH            0
# dtype: int64

# %%
new_Fdata.describe()
# Out:
#                 PM1         PM2.5          PM10          Temp      Humidity  \
# count  23536.000000  23536.000000  23536.000000  23536.000000  23536.000000
# mean       8.702683     13.812033     16.901513     40.956917     33.841519
# std        5.351700      7.878017     10.853705      8.789028     39.406609
# min        0.000000      0.000000    -20.000000    -21.000000    -24.000000
# 25%        4.000000      8.000000      9.000000     37.000000      3.000000
# 50%        8.000000     13.000000     15.000000     43.000000     10.000000
# 75%       12.000000     19.000000     23.000000     45.000000     81.000000
# max       43.000000     54.000000     92.000000     90.000000     95.000000
#
#               Light            CO     Water Temp            pH
# count  23536.000000  23536.000000   23536.000000  23536.000000
# mean      37.274059     92.548372    1049.335440    388.820988
# std       10.558374     12.979871   15720.379888   4701.319000
# min       23.440000      6.300000       6.250000      6.201900
# 25%       34.000000     95.000000      24.810000      6.380000
# 50%       35.000000     95.000000      26.130000      6.440000
# 75%       37.000000     95.000000      27.190000      6.520000
# max       95.000000     95.002019  292019.000000  62019.000000

# %%
new_Fdata = Fdata.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)

# %%
new_Fdata.shape
# Out:
# (23460, 9)

# %%
Fish_cor= new_Fdata.corr()

# %%
Fish_cor
# Out:
#                  PM1     PM2.5      PM10      Temp  Humidity     Light  \
# PM1         1.000000  0.866753  0.690780  0.340641 -0.390958 -0.169861
# PM2.5       0.866753  1.000000  0.853848  0.268702 -0.394306  0.029463
# PM10        0.690780  0.853848  1.000000  0.200770 -0.345095  0.375605
# Temp        0.340641  0.268702  0.200770  1.000000 -0.219991 -0.214532
# Humidity   -0.390958 -0.394306 -0.345095 -0.219991  1.000000 -0.073072
# Light      -0.169861  0.029463  0.375605 -0.214532 -0.073072  1.000000
# CO          0.120442 -0.134070 -0.403996  0.198307 -0.043825 -0.880002
# Water Temp  0.017889  0.012024  0.005344  0.006192 -0.011509 -0.013283
# pH          0.006279  0.001606  0.002063  0.001312 -0.001618  0.000061
#
#                   CO  Water Temp        pH
# PM1         0.120442    0.017889  0.006279
# PM2.5      -0.134070    0.012024  0.001606
# PM10       -0.403996    0.005344  0.002063
# Temp        0.198307    0.006192  0.001312
# Humidity   -0.043825   -0.011509 -0.001618
# Light      -0.880002   -0.013283  0.000061
# CO          1.000000    0.011033  0.000067
# Water Temp  0.011033    1.000000 -0.005224
# pH          0.000067   -0.005224  1.000000

# %%
plt.figure(figsize=(12, 8), dpi=80)
sns.heatmap(Fdata.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12, 8), dpi=80)
sns.heatmap(Fish_cor.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
Fdata.corr()
# Out:
#                  PM1     PM2.5      PM10      Temp  Humidity     Light  \
# PM1         1.000000  0.867224  0.691828  0.341465 -0.393001 -0.168693
# PM2.5       0.867224  1.000000  0.854393  0.269756 -0.396546  0.030350
# PM10        0.691828  0.854393  1.000000  0.201950 -0.347317  0.375747
# Temp        0.341465  0.269756  0.201950  1.000000 -0.221119 -0.214004
# Humidity   -0.393001 -0.396546 -0.347317 -0.221119  1.000000 -0.073887
# Light      -0.168693  0.030350  0.375747 -0.214004 -0.073887  1.000000
# CO          0.119685 -0.134391 -0.403810  0.197943 -0.043138 -0.879996
# Water Temp  0.018041  0.012211  0.005533  0.006270 -0.011684 -0.013222
# pH          0.006498  0.001868  0.002306  0.001413 -0.001865  0.000135
#
#                   CO  Water Temp        pH
# PM1         0.119685    0.018041  0.006498
# PM2.5      -0.134391    0.012211  0.001868
# PM10       -0.403810    0.005533  0.002306
# Temp        0.197943    0.006270  0.001413
# Humidity   -0.043138   -0.011684 -0.001865
# Light      -0.879996   -0.013222  0.000135
# CO          1.000000    0.010992  0.000018
# Water Temp  0.010992    1.000000 -0.005206
# pH          0.000018   -0.005206  1.000000

# %%
Fish_cor.corr()
# Out:
#                  PM1     PM2.5      PM10      Temp  Humidity     Light  \
# PM1         1.000000  0.956757  0.799577  0.537873 -0.788813 -0.114510
# PM2.5       0.956757  1.000000  0.933263  0.416493 -0.781283  0.152123
# PM10        0.799577  0.933263  1.000000  0.244308 -0.709611  0.486608
# Temp        0.537873  0.416493  0.244308  1.000000 -0.522628 -0.388521
# Humidity   -0.788813 -0.781283 -0.709611 -0.522628  1.000000 -0.077472
# Light      -0.114510  0.152123  0.486608 -0.388521 -0.077472  1.000000
# CO          0.060254 -0.211490 -0.533236  0.367291  0.041512 -0.985963
# Water Temp -0.173142 -0.176103 -0.179515 -0.152429  0.015066 -0.032818
# pH         -0.203019 -0.199714 -0.189383 -0.173828  0.040739 -0.004765
#
#                   CO  Water Temp        pH
# PM1         0.060254   -0.173142 -0.203019
# PM2.5      -0.211490   -0.176103 -0.199714
# PM10       -0.533236   -0.179515 -0.189383
# Temp        0.367291   -0.152429 -0.173828
# Humidity    0.041512    0.015066  0.040739
# Light      -0.985963   -0.032818 -0.004765
# CO          1.000000    0.036650  0.011080
# Water Temp  0.036650    1.000000 -0.140346
# pH          0.011080   -0.140346  1.000000

# %%
uncleanCarbon = pd.DataFrame()
cleanedCarbon = pd.DataFrame()
uncleanCarbon=Fdata_LD['Carbon Monoxide']
cleanedCarbon=Fdata['Carbon Monoxide']
CarbonCompare_deleteMissing = pd.concat([uncleanCarbon, cleanedCarbon], axis=1)
CarbonCompare_deleteMissing.columns = ['Carbon Monoxide','Fixed Carbon Monoxide']
CarbonCompare_deleteMissing.plot(figsize=(30,15),use_index=True, subplots=bool)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
Fdata_AIM = Fdata
Fdata_AIM.mean()
Fdata_AIM.fillna(Fdata_AIM.mean(), inplace=True)

# %%
uncleanCarbon = pd.DataFrame()
cleanedCarbon = pd.DataFrame()
unclean_humidity=Fdata_AIM['humidity']
cleaned_humidity=Fdata['humidity']
CarbonCompare_fillAverage = pd.concat([unclean_humidity, cleaned_humidity], axis=1)
CarbonCompare_fillAverage.columns = ['humidity','Fixed humidity']
CarbonCompare_fillAverage.plot(figsize=(30,15),use_index=True,subplots=bool)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
Fdata_EG = Fdata
Fdata_EG.interpolate(method='nearest')
# Out:
#         Month   Day  Hour  Minute  Second  Carbon Monoxide  \
# 0         6.0  18.0  14.0    30.0    43.0            201.0
# 1         6.0  18.0  14.0    30.0    48.0            201.0
# 2         6.0  18.0  14.0    31.0     3.0            201.0
# 3         6.0  18.0  14.0    31.0     8.0            201.0
# 4         6.0  18.0  14.0    31.0    13.0            201.0
# ...       ...   ...   ...     ...     ...              ...
# 811941   10.0  19.0   8.0    24.0     4.0            201.0
# 811942   10.0  19.0   8.0    24.0     8.0            201.0
# 811943   10.0  19.0   8.0    24.0    13.0           -168.0
# 811944   10.0  19.0   8.0    24.0    16.0            201.0
# 811945   10.0  19.0   8.0    24.0    20.0            201.0
#
#         external temperature  PM 2.5  external temp  humidity  \
# 0                       25.0    29.0          95.00     27.19
# 1                       25.0    29.0          95.00     27.19
# 2                       25.0    29.0          95.00     27.19
# 3                       25.0    29.0          95.00     27.19
# 4                       25.0    29.0          95.00     27.25
# ...                      ...     ...            ...       ...
# 811941                -165.0    25.0          95.00     25.94
# 811942                -167.0    25.0          95.00     25.94
# 811943                  25.0    95.0          25.94      4.18
# 811944                -169.0    25.0          95.00     25.94
# 811945                -169.0    25.0          95.00     25.94
#
#         internal temperature
# 0                    4.39000
# 1                    4.38000
# 2                    4.38000
# 3                    4.41000
# 4                    4.41000
# ...                      ...
# 811941               4.17000
# 811942               4.19000
# 811943              82.74487
# 811944               4.17000
# 811945               4.17000
#
# [811946 rows x 11 columns]

# %%
uncleanCarbon = pd.DataFrame()
cleanedCarbon = pd.DataFrame()
unclean_humidity=Fdata_EG['humidity']
cleaned_humidity=Fdata['humidity']
CarbonCompare_FillNearestValue= pd.concat([unclean_humidity, cleaned_humidity], axis=1)
CarbonCompare_FillNearestValue.columns = ['humidity','Fixed humidity']
CarbonCompare_FillNearestValue.plot(figsize=(30,15),use_index=True,subplots=bool)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)
